# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizkiyatul/Studi_Independen/blob/main/Copy_of_Integrasikan_Kaggle_dan_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kita bisa mengintegrasikan secara langsung antara sebuah dataset pada kaggle.com dengan notebook kita menggunakan API yang telah disediakan oleh kaggle. Hal ini memiliki keuntungan bahwa kita tidak perlu upload dataset yang kita download pada drive local kita ke google colab, cukup langsung download ke colab menggunakan API.
#
# ## 1. Download Kaggle API
# Kaggle API didapat dengan mengikuti langkah - langkah berikut:
#
#
# *   Masuk ke kolom **profile**
#
#
# ![Kaggle API - 1 (3).PNG](data:image/png;base64,...)

# %% [markdown]
# *   Pilih kolom **Account**
# ![Kaggle API - 2 (2).PNG](data:image/png;base64,...)

# %% [markdown]
# *   Pilih create new **API Token** pada tabel API
# ![Kaggle API - 3 (2).PNG](data:image/png;base64,...)

# %% [markdown]
# ## 2. Upload file kaggle.json dan install Kaggle

# %%
# !pip install kaggle

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 3. Copy API Command dan Download Dataset
# padasesi ini kita menggunakan datasets Emotion detection dari kaggle.com
#
# ![Kaggle API - 4.PNG](data:image/png;base64,...)

# %%
# !kaggle datasets download -d ananthu017/emotion-detection-fer
# Out:
# ...
#  87% 57.0M/65.2M [00:00<00:00, 74.0MB/s]
# 100% 65.2M/65.2M [00:00<00:00, 71.5MB/s]

# %%
# !kaggle datasets download -d ananthu017/emotion-detection-fer
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 166, in authenticate
#     self.config_file, self.config_dir))
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !unzip '/content/emotion-detection-fer.zip' -d '/content/emotion-detection-fer'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/emotion-detection-fer/train/sad/im37.png
#   inflating: /content/emotion-detection-fer/train/sad/im370.png
#   inflating: /content/emotion-detection-fer/train/sad/im3700.png
#   inflating: /content/emotion-detection-fer/train/sad/im3701.png
#   inflating: /content/emotion-detection-fer/train/sad/im3702.png
#   inflating: /content/emotion-detection-fer/train/sad/im3703.png
#   inflating: /content/emotion-detection-fer/train/sad/im3704.png
#   inflating: /content/emotion-detection-fer/train/sad/im3705.png
#   inflating: /content/emotion-detection-fer/train/sad/im3706.png
#   inflating: /content/emotion-detection-fer/train/sad/im3707.png
#   inflating: /content/emotion-detection-fer/train/sad/im3708.png
#   inflating: /content/emotion-detection-fer/train/sad/im3709.png
#   inflating: /content/emotion-detection-fer/train/sad/im371.png
#   inflating: /content/emotion-detection-fer/train/sad/im3710.png
# ...

# %%
# !unzip '/content/emotion-detection-fer.zip' -d '/content/emotion-detection-fer'
# Out:
# unzip:  cannot find or open /content/emotion-detection-fer.zip, /content/emotion-detection-fer.zip.zip or /content/emotion-detection-fer.zip.ZIP.
